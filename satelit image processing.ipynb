# %%
from PIL import Image
import numpy as np
import random
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img = Image.open('/Users/DEBBY ROBIYANTI/Documents/0_0/semester 7/Pengolahan Citra Digital/Himawari/16 okt 2021.jpg')
pic = np.array(img)

# %%
blue_mask = pic[ :, :, 2] < 200
pic[blue_mask] = 0
plt.figure(figsize=(14,14))
plt.imshow(pic)

# %%
img1 = Image.open('/Users/DEBBY ROBIYANTI/Documents/0_0/semester 7/Pengolahan Citra Digital/Himawari/Dingin/14.png')
img2 = Image.open('/Users/DEBBY ROBIYANTI/Documents/0_0/semester 7/Pengolahan Citra Digital/Himawari/Dingin/15.png')
img3 = Image.open('/Users/DEBBY ROBIYANTI/Documents/0_0/semester 7/Pengolahan Citra Digital/Himawari/Dingin/16.png')

pic1 = np.array(img1)
pic2 = np.array(img2)
pic3 = np.array(img3)

# %%
plt.figure(figsize=(15,15))
plt.imshow(pic1)

# %%
print('Type of image :', type(pic1))
print()
print('Shape of the image : {}'. format(pic1.shape) )
print('Image hight : {}'. format(pic1.shape[0]) )
print('Image Width : {}'. format(pic1.shape[1]) )
print('Dimension of Image : {}'. format(pic1.ndim))
# Out:
# Type of image : <class 'numpy.ndarray'>
#
# Shape of the image : (496, 754, 4)
# Image hight : 496
# Image Width : 754
# Dimension of Image : 3

# %%
print('Type of image :', type(pic1))
print()
print('Shape of the image : {}'. format(pic1.shape) )
print('Image hight : {}'. format(pic1.shape[0]) )
print('Image Width : {}'. format(pic1.shape[1]) )
print('Dimension of Image : {}'. format(pic1.ndim))
# Out:
# Type of image : <class 'numpy.ndarray'>
#
# Shape of the image : (500, 750, 3)
# Image hight : 500
# Image Width : 750
# Dimension of Image : 3

# %% [markdown]
# Resize all image in directory

# %%
from PIL import Image
import os, sys

path = "/Users/DEBBY ROBIYANTI/Documents/0_0/semester 7/Pengolahan Citra Digital/Himawari/blue/"
dirs = os.listdir( path )

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((750,500), Image.ANTIALIAS)
            imResize.save(f + ' resized.png', 'JPEG', quality=90)

resize()

# %% [markdown]
# Get Average of Mutiple Image

# %%
# Access all files in directory
allfiles = os.listdir(os.getcwd())
imlist = [filename for filename in allfiles if filename[-4:] in [".png",".PNG"]]

# %%
allfiles
# Out:
# ['14.jpg', '15.jpg', '16.jpg', '17.jpg', '18.jpg']

# %%
imlist[0]
# Out:
# '14.jpg'

# %%
# Assuming all images are the same size, get dimensions of first image
w,h=Image.open(imlist[0]).size
#N=len(imlist)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-125-738f834705f2> in <module>
#       1 # Assuming all images are the same size, get dimensions of first image
# ----> 2 w,h=Image.open(imlist[0]).size
#       3 #N=len(imlist)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: '14.jpg'

# %%
# Create a numpy array of floats to store the average (assume RGB images)
arr=numpy.zeros((h,w,3),numpy.float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-ed635ee34154> in <module>
#       1 # Create a numpy array of floats to store the average (assume RGB images)
# ----> 2 arr=numpy.zeros((h,w,3),numpy.float)
#
# NameError: name 'h' is not defined

# %%
# Build up average pixel intensities, casting each image as an array of floats
for im in imlist:
    imarr=numpy.array(Image.open(im),dtype=numpy.float)
    arr=arr+imarr/N

# %%
# Round values in array and cast as 8-bit integer
arr=numpy.array(numpy.round(arr),dtype=numpy.uint8)

# %%
# Generate, save and preview final image
out=Image.fromarray(arr,mode="RGB")
out.save("Average.png")
out.show()
